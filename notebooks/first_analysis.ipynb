# %%
sentinel_by_id['sentinel'].plot(kind='hist', bins=20, figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
top_ids = [120, 344, 345]

daily.loc[top_ids]['sentinel'].unstack(0).plot(figsize=(10,5))
# Out:
# <Axes: xlabel='date'>

# %%
daily.loc[120]['sentinel'].plot(kind='line', figsize=(10,4), title='Daily Sentinel Rate for Individual 120')
# Out:
# <Axes: title={'center': 'Daily Sentinel Rate for Individual 120'}, xlabel='date'>

# %%
daily = (
    df.groupby(['id', 'date'])['behaviour']
      .value_counts(normalize=True)
      .unstack()
      .fillna(0)
)

daily.loc[[120, 344, 345]].head(10)
# Out:
# behaviour       not_sentinel  sentinel
# id  date
# 120 2014-12-01           1.0       0.0
#     2014-12-03           1.0       0.0
#     2014-12-04           0.0       1.0
#     2014-12-05           0.0       1.0
#     2014-12-06           0.0       1.0
#     2014-12-07           1.0       0.0
#     2014-12-08           0.0       1.0
#     2014-12-13           0.0       1.0
#     2014-12-14           1.0       0.0
#     2014-12-15           0.0       1.0

# %%
df['date'] = pd.to_datetime(df['time'], dayfirst=True).dt.date

# %%
df['id'].value_counts().loc[[120, 344, 345, 122, 346]]
# Out:
# id
# 120    66
# 344    64
# 345    34
# 122    39
# 346    35
# Name: count, dtype: int64

# %%
df['id'].value_counts().head(10)
# Out:
# id
# 523    189
# 716    171
# 292    147
# 97     143
# 713    142
# 387    128
# 125    126
# 383    126
# 54     126
# 71     123
# Name: count, dtype: int64

# %%
sentinel_by_id = (
    df.groupby('id')['behaviour']
      .value_counts(normalize=True)
      .unstack()
      .fillna(0)
)

sentinel_by_id.sort_values('sentinel', ascending=False).head(10)
# Out:
# behaviour  not_sentinel  sentinel
# id
# 120            0.121212  0.878788
# 344            0.125000  0.875000
# 345            0.176471  0.823529
# 122            0.230769  0.769231
# 346            0.257143  0.742857
# 555            0.312500  0.687500
# 579            0.319149  0.680851
# 580            0.348837  0.651163
# 75             0.358491  0.641509
# 378            0.383562  0.616438

# %%
df.groupby('id')['behaviour'].value_counts(normalize=True).unstack()
# Out:
# behaviour  not_sentinel  sentinel
# id
# 1              0.772727  0.227273
# 2              1.000000       NaN
# 3              1.000000       NaN
# 4              1.000000       NaN
# 5              0.950000  0.050000
# ..                  ...       ...
# 746            1.000000       NaN
# 747            1.000000       NaN
# 748            1.000000       NaN
# 749            1.000000       NaN
# 750            1.000000       NaN
#
# [750 rows x 2 columns]

# %%
sentinel_rate = df['behaviour'].value_counts(normalize=True)
sentinel_rate
# Out:
# behaviour
# not_sentinel    0.862058
# sentinel        0.137942
# Name: proportion, dtype: float64

# %%
df['behaviour'].value_counts()
# Out:
# behaviour
# not_sentinel    24804
# sentinel         3969
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (28773, 3)

# %%
import pandas as pd

df = pd.read_csv("../data/meerkats.csv")
df.head()
# Out:
#    id        time     behaviour
# 0   5  01.12.2009  not_sentinel
# 1   6  01.12.2009  not_sentinel
# 2   7  01.12.2009  not_sentinel
# 3  20  01.12.2009  not_sentinel
# 4  23  01.12.2009  not_sentinel
